# %% [markdown]
# <a href="https://colab.research.google.com/github/Vedant988/RemovingStopWords/blob/main/RemovingStopWords.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing library
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np
from google.colab import files
import nltk
import string
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# imporing csv file from google drive using google.colab in COLAB
# from google.colab import drive
# drive.mount("/content/drive")

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
#reading csv by using pandas command!
import pandas as pd
path = "/content/drive/MyDrive/Blackcoffer intern/InputCSV.csv"
df = pd.read_csv(path)
df
# Out:
#               URL_ID                                                URL  \
# 0    blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1    blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2    blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3    blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4    blackassign0005  https://insights.blackcoffer.com/ott-platform-...
# ..               ...                                                ...
# 926              NaN                                                NaN
# 927              NaN                                                NaN
# 928              NaN                                                NaN
# 929              NaN                                                NaN
# 930              NaN                                                NaN
#
#      Unnamed: 2  Unnamed: 3  Unnamed: 4
# 0           NaN         NaN         NaN
# 1           NaN         NaN         NaN
# 2           NaN         NaN         NaN
# 3           NaN         NaN         NaN
# 4           NaN         NaN         NaN
# ..          ...         ...         ...
# 926         NaN         NaN         NaN
# 927         NaN         NaN         NaN
# 928         NaN         NaN         NaN
# 929         NaN         NaN         NaN
# 930         NaN         NaN         NaN
#
# [931 rows x 5 columns]

# %%
#setiing the limit of dataframe!
df=df.iloc[0:100]
df
# Out:
#              URL_ID                                                URL  \
# 0   blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1   blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2   blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3   blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4   blackassign0005  https://insights.blackcoffer.com/ott-platform-...
# ..              ...                                                ...
# 95  blackassign0096  https://insights.blackcoffer.com/what-is-the-r...
# 96  blackassign0097  https://insights.blackcoffer.com/impact-of-cov...
# 97  blackassign0098  https://insights.blackcoffer.com/contribution-...
# 98  blackassign0099  https://insights.blackcoffer.com/how-covid-19-...
# 99  blackassign0100  https://insights.blackcoffer.com/how-will-covi...
#
#     Unnamed: 2  Unnamed: 3  Unnamed: 4
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# ..         ...         ...         ...
# 95         NaN         NaN         NaN
# 96         NaN         NaN         NaN
# 97         NaN         NaN         NaN
# 98         NaN         NaN         NaN
# 99         NaN         NaN         NaN
#
# [100 rows x 5 columns]

# %% [markdown]
# ---

# %% [markdown]
# # Droping URL ID Column

# %%
#deleting URL_ID column from dataframe
df.drop(df.columns[1],axis=1,inplace=True)
df
# Out:
# <ipython-input-72-b40a09b4516d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(df.columns[1],axis=1,inplace=True)
#                                                   URL  Unnamed: 3  Unnamed: 4
# 0   https://insights.blackcoffer.com/rising-it-cit...         NaN         NaN
# 1   https://insights.blackcoffer.com/rising-it-cit...         NaN         NaN
# 2   https://insights.blackcoffer.com/internet-dema...         NaN         NaN
# 3   https://insights.blackcoffer.com/rise-of-cyber...         NaN         NaN
# 4   https://insights.blackcoffer.com/ott-platform-...         NaN         NaN
# ..                                                ...         ...         ...
# 95  https://insights.blackcoffer.com/what-is-the-r...         NaN         NaN
# 96  https://insights.blackcoffer.com/impact-of-cov...         NaN         NaN
# 97  https://insights.blackcoffer.com/contribution-...         NaN         NaN
# 98  https://insights.blackcoffer.com/how-covid-19-...         NaN         NaN
# 99  https://insights.blackcoffer.com/how-will-covi...         NaN         NaN
#
# [100 rows x 3 columns]

# %% [markdown]
# ---

# %% [markdown]
# # Importing StopWords

# %%
#importing nltk library and stopwords
import nltk
import string
punc=[punc for punc in string.punctuation]
#text.drop(1,axis=1,inplace=True)

# %%
import pandas as pd

# Read StopWords files
StopWords_Auditor = pd.read_csv("/content/drive/MyDrive/Blackcoffer intern/stopword/StopWords_Auditor.txt", header=None)
StopWords_Currencies = pd.read_csv("/content/drive/MyDrive/Blackcoffer intern/stopword/StopWords_Currencies.txt", header=None, encoding="ISO-8859-1", sep='|')
StopWords_DatesandNumbers = pd.read_csv("/content/drive/MyDrive/Blackcoffer intern/stopword/StopWords_DatesandNumbers.txt", header=None)
StopWords_Generic_df = pd.read_csv("/content/drive/MyDrive/Blackcoffer intern/stopword/StopWords_Generic.txt", header=None)
StopWords_GenericLong = pd.read_csv("/content/drive/MyDrive/Blackcoffer intern/stopword/StopWords_GenericLong.txt", header=None)
StopWords_Geographic = pd.read_csv("/content/drive/MyDrive/Blackcoffer intern/stopword/StopWords_Geographic.txt", header=None)
StopWords_Names = pd.read_csv("/content/drive/MyDrive/Blackcoffer intern/stopword/StopWords_Names.txt", header=None)
StopWords_Currencies = StopWords_Currencies.drop([1],axis=True)
StopWords_Auditor_path = "/content/drive/MyDrive/Blackcoffer intern/stopword/StopWords_Auditor.txt"
StopWords_Currencies_path = "/content/drive/MyDrive/Blackcoffer intern/stopword/StopWords_Currencies.txt"
StopWords_DatesandNumbers_path = "/content/drive/MyDrive/Blackcoffer intern/stopword/StopWords_DatesandNumbers.txt"
StopWords_Generic_path = "/content/drive/MyDrive/Blackcoffer intern/stopword/StopWords_Generic.txt"
StopWords_GenericLong_path = "/content/drive/MyDrive/Blackcoffer intern/stopword/StopWords_GenericLong.txt"
StopWords_Geographic_path = "/content/drive/MyDrive/Blackcoffer intern/stopword/StopWords_Geographic.txt"
StopWords_Names_path = "/content/drive/MyDrive/Blackcoffer intern/stopword/StopWords_Names.txt"

# %% [markdown]
# ---

# %% [markdown]
# # Making List Of StopWords

# %%
import csv

# Create empty lists to store stop words
StopWords_Auditor_list = []
StopWords_DatesandNumbers_list = []
StopWords_Generic_list = []
StopWords_GenericLong_list = []
StopWords_Geographic_list = []
StopWords_Names_list = []

# Function to read stop words files and append to respective lists
def read_stop_words(file_path, target_list):
    with open(file_path, newline="") as file:
        csv_reader = csv.reader(file)
        for row in csv_reader:
            target_list.append(row[0])

# Read StopWords_Auditor
read_stop_words(StopWords_Auditor_path, StopWords_Auditor_list)

# Read StopWords_DatesandNumbers
read_stop_words(StopWords_DatesandNumbers_path, StopWords_DatesandNumbers_list)

# Read StopWords_Generic
read_stop_words(StopWords_Generic_path, StopWords_Generic_list)

# Read StopWords_GenericLong
read_stop_words(StopWords_GenericLong_path, StopWords_GenericLong_list)

# Read StopWords_Geographic
read_stop_words(StopWords_Geographic_path, StopWords_Geographic_list)

# Assuming StopWords_Currencies is your DataFrame
# Extract values from the first column into a list
StopWords_Currencies_list = StopWords_Currencies.iloc[:, 0].tolist()

# Read StopWords_Names
read_stop_words(StopWords_Names_path, StopWords_Names_list)

# %% [markdown]
# ---

# %% [markdown]
# # Importing Punc

# %%
from nltk.corpus import stopwords
punc=[punc for punc in string.punctuation]

# %% [markdown]
# ---

# %% [markdown]
# # Downloading Txt Fil

# %%
url_id = 1
for i in range(0, len(df)):
    j = df.iloc[i].values
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36'
    }
    page = requests.get(j[0], headers=headers)  # loading text in url
    soup = BeautifulSoup(page.content, 'html.parser')  # parsing url text
    content = soup.findAll(attrs={'class': 'td-post-content'})  # extracting only text part

    # Check if content is empty
    if content:
        content = content[0].text.replace('\xa0', "  ").replace('\n', "  ")  # replace end line symbol with space
        title = soup.findAll(attrs={'class': 'entry-title'})  # extracting title of website

        # Check if title is empty
        if title and len(title) > 16:
            title = title[16].text.replace('\n', "  ").replace('/', "")
            text = title + '.' + content  # merging title and content text
            text = np.array(text)  # converting to array form
            text.reshape(1, -1)  # changing shape to 1d
            df1 = pd.Series(text)  # creating series data frame
            b = str(url_id)+"."+'txt'  # name of the text file
            url_id += 1
            # with open(b, 'a') as f:#creating text file
            #    df1.to_csv(f, line_terminator=',', index=False, header=False)
            # files.download(b)#downloading text file
        else:
            print(f"Title not found for URLID {url_id} - {j[0]}")
            url_id += 1
    else:
        print(f"Content not found for URL ID {url_id} - {j[0]}")
        url_id += 1

#this will actually show in which url the error is occuring!
# Out:
# Content not found for URL ID 36 - https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/
# Content not found for URL ID 49 - https://insights.blackcoffer.com/covid-19-environmental-impact-for-the-future/

# %%
text=pd.read_csv("/content/100.txt",header=None)
text.drop(1,axis=1,inplace=True)
text=text.astype(str)
import re
a=text[0].str.split('([\.]\s)',expand=False)#splitting text on '.'
b=a.explode()#converting to rows
b=pd.DataFrame(b)#creating data frame
b.columns=['abc']
#removing . char from each rows
def abcd(x):
    nopunc =[char for char in x if char != '.']
    return ''.join(nopunc)
b['abc']=b['abc'].apply(abcd)
#replacing emty space with null values
c=b.replace('',np.nan,regex=True)
c=c.mask(c==" ")
c=c.dropna()
c.reset_index(drop=True,inplace=True)
# Out:
#                                                    0
# 0  Grafana Dashboard to visualize and analyze sen...

# %%
#creating func for removing stop words
def text_process(text):
    nopunc =[char for char in text if char not in punc or char not in [':',',','(',')','’','?']]
    nopunc=''.join(nopunc)
    txt=' '.join([word for word in nopunc.split() if word.lower() not in StopWords_Auditor])
    txt1=' '.join([word for word in txt.split() if word.lower() not in StopWords_Currencies])
    txt2=' '.join([word for word in txt1.split() if word.lower() not in StopWords_DatesandNumbers])
    txt3=' '.join([word for word in txt2.split() if word.lower() not in StopWords_Generic_df])
    txt4=' '.join([word for word in txt3.split() if word.lower() not in StopWords_GenericLong])
    txt5=' '.join([word for word in txt4.split() if word.lower() not in StopWords_Geographic])
    return ' '.join([word for word in txt5.split() if word.lower() not in StopWords_Names])
#applying func for each row
c['abc']=c['abc'].apply(text_process)
c
# Out:
#                                                   abc
# 0   Grafana Dashboard to visualize and analyze sen...
# 1   As business close to help prevent transmission...
# 2                     COVID-19 is in decline in China
# 3   There are now more new cases every day in Euro...
# 4   The Human Consequences In recent weeks we have...
# 5   Travel and tourism account for 10% of the glob...
# 6   Global tourism travel and hospitality companie...
# 7   This in turn affects many people typically the...
# 8   Some governments have announced economic measu...
# 9   Behind these statistics lie the human costs of...
# 10  Not knowing how this pandemic will play out af...
# 11  Fear of the unknown can often lead to feelings...
# 12  In all cases lack of information or the wrong ...
# 13  There is a huge amount of misleading informati...
# 14  People are susceptible to social media posts f...
# 15  Sadly criminals and hackers are also exploitin...
# 16  Hackers are selling malware and hacking tools ...
# 17  Social distancing and lockdowns have also prom...
# 18  Many people report being bored or concerned ab...
# 19  The downside of self-isolation or social lockd...
# 20  This stress and anxiety can lead to increased ...
# 21  Essential Actions From The Business Community ...
# 22  It is important for businesses to show solidar...
# 23  Daily updates on a company website with input ...
# 24  This is particularly true for large companies ...
# 25  Messages about what businesses are doing for t...
# 26  Some companies are helping schoolchildren from...
# 27  Even CEOs can show they are working from home ...
# 28  Following WHO advice there is a need for the b...
# 29  Of these items 20 are either not available loc...
# 30  These missing items fall into four categories ...
# 31  The call for action is for more money to work ...
# 32  The concept is to create a global security sto...

# %%
#importing master Dictionary
positive=pd.read_csv("/content/drive/MyDrive/Blackcoffer intern/Master Directory/positive-words.txt")
negative=pd.read_csv("/content/drive/MyDrive/Blackcoffer intern/Master Directory/negative-words.txt",header=None,encoding="ISO-8859-1")
positive.columns=['abc']
negative.columns=['abc']
positive['abc']=positive['abc'].astype(str)
negative['abc']=negative['abc'].astype(str)
#positive and negative dictionary without stopwords
positive['abc']=positive['abc'].apply(text_process)
negative['abc']=negative['abc'].apply(text_process)

# %%
#positive list
length=positive.shape[0]
post=[]
for i in range(0,length):
   nopunc =[char for char in positive.iloc[i] if char not in string.punctuation or char != '+']
   nopunc=''.join(nopunc)

   post.append(nopunc)
#negative list
length=negative.shape[0]
neg=[]
for i in range(0,length):
  nopunc =[char for char in negative.iloc[i] if char not in string.punctuation or char != '+']
  nopunc=''.join(nopunc)
  neg.append(nopunc)

# %% [markdown]
# ---

# %% [markdown]
# # Tokenizing the text

# %%
from nltk import word_tokenize
txt_list=[]
length=c.shape[0]
for i in range(0,length):
  txt=' '.join([word for word in c.iloc[i]])
  txt_list.append(txt)
#tokenization of text
tokenize_text=[]
for i in txt_list:
  tokenize_text+=(word_tokenize(i))
print(tokenize_text)
# Out:
# ['Grafana', 'Dashboard', 'to', 'visualize', 'and', 'analyze', 'sensors', '’', 'data', 'As', 'business', 'close', 'to', 'help', 'prevent', 'transmission', 'of', 'COVID-19', 'financial', 'concerns', 'and', 'job', 'losses', 'are', 'one', 'of', 'the', 'first', 'human', 'impacts', 'of', 'the', 'virus', ';', 'Not', 'knowing', 'how', 'this', 'pandemic', 'will', 'play', 'out', 'also', 'affects', 'our', 'economic', 'physical', 'and', 'mental', 'well-being', ';', 'Despite', 'this', 'fear', 'businesses', 'and', 'communities', 'in', 'many', 'regions', 'have', 'shown', 'a', 'more', 'altruistic', 'response', 'in', 'the', 'face', 'of', 'crisis', '–', 'actions', 'which', 'could', 'help', 'countries', 'preparing', 'for', 'COVID-19', 'COVID-19', 'is', 'in', 'decline', 'in', 'China', 'There', 'are', 'now', 'more', 'new', 'cases', 'every', 'day', 'in', 'Europe', 'than', 'there', 'were', 'in', 'China', 'at', 'the', 'epidemic', '’', 's', 'peak', 'and', 'Italy', 'has', 'surpassed', 'it', 'as', 'the', 'country', 'with', 'the', 'most', 'deaths', 'from', 'the', 'virus', 'It', 'took', '67', 'days', 'to', 'reach', 'the', 'first', '100000', 'confirmed', 'cases', 'worldwide', '11', 'days', 'for', 'this', 'to', 'increase', 'to', '200000and', 'just', 'four', 'to', 'reach', '300000', 'confirmed', 'cases', '–', 'a', 'figure', 'now', 'exceeded', 'The', 'Human', 'Consequences', 'In', 'recent', 'weeks', 'we', 'have', 'seen', 'the', 'significant', 'economic', 'impact', 'of', 'the', 'coronavirus', 'on', 'financial', 'markets', 'and', 'vulnerable', 'industries', 'such', 'as', 'manufacturing', 'tourism', 'hospitality', 'and', 'travel', 'Travel', 'and', 'tourism', 'account', 'for', '10', '%', 'of', 'the', 'global', 'GDP', 'and', '50', 'million', 'jobs', 'are', 'at', 'risk', 'worldwide', 'Global', 'tourism', 'travel', 'and', 'hospitality', 'companies', 'closing', 'down', 'affects', 'SMEs', 'globally', 'This', 'in', 'turn', 'affects', 'many', 'people', 'typically', 'the', 'least', 'well-paid', 'and', 'those', 'self-employed', 'or', 'working', 'in', 'informal', 'environments', 'in', 'the', 'gig', 'economy', 'or', 'in', 'part-time', 'work', 'with', 'zero-hours', 'contracts', 'Some', 'governments', 'have', 'announced', 'economic', 'measures', 'to', 'safeguard', 'jobs', 'guarantee', 'wages', 'and', 'support', 'the', 'self-employed', 'but', 'there', 'is', 'a', 'lack', 'of', 'clarity', 'in', 'many', 'countries', 'about', 'how', 'these', 'measures', 'will', 'be', 'implemented', 'and', 'how', 'people', 'will', 'manage', 'a', 'loss', 'of', 'income', 'in', 'the', 'short-term', 'Behind', 'these', 'statistics', 'lie', 'the', 'human', 'costs', 'of', 'the', 'pandemic', 'from', 'the', 'deaths', 'of', 'friends', 'and', 'family', 'to', 'the', 'physical', 'effects', 'of', 'infection', 'and', 'the', 'mental', 'trauma', 'and', 'fear', 'faced', 'by', 'almost', 'everyone', 'Not', 'knowing', 'how', 'this', 'pandemic', 'will', 'play', 'out', 'affects', 'our', 'economic', 'physical', 'and', 'mental', 'well-being', 'against', 'a', 'backdrop', 'of', 'a', 'world', 'that', 'for', 'many', 'is', 'increasingly', 'anxious', 'unhappy', 'and', 'lonely', 'Fear', 'of', 'the', 'unknown', 'can', 'often', 'lead', 'to', 'feelings', 'of', 'panic', 'for', 'example', 'when', 'people', 'feel', 'they', 'are', 'being', 'denied', 'life-saving', 'protection', 'or', 'treatment', 'or', 'that', 'they', 'may', 'run', 'out', 'of', 'necessities', 'which', 'can', 'lead', 'to', 'panic', 'buyingPsychological', 'stress', 'is', 'often', 'related', 'to', 'a', 'sense', 'of', 'a', 'lack', 'of', 'control', 'in', 'the', 'face', 'of', 'uncertainty', 'In', 'all', 'cases', 'lack', 'of', 'information', 'or', 'the', 'wrong', 'information', 'either', 'provided', 'inadvertently', 'or', 'maliciously', 'can', 'amplify', 'the', 'effects', 'There', 'is', 'a', 'huge', 'amount', 'of', 'misleading', 'information', 'circulating', 'online', 'about', 'COVID-19', 'from', 'fake', 'medical', 'information', 'to', 'speculation', 'about', 'government', 're ...

# %%
len(tokenize_text)
# Out:
# 1081

# %% [markdown]
# ---

# %%
#POsitive sCore
positive_score=0
for i in tokenize_text:
  if(i.lower() in post):
    positive_score+=1
print('postive score=', positive_score)

#NEgative Score
negative_score=0
for i in tokenize_text:
  if(i.lower() in neg):
    negative_score+=1
print('negative score=', negative_score)

#Polarity Score = (Positive Score – Negative Score)/ ((Positive Score + Negative Score) + 0.000001)
Polarity_Score=(positive_score-negative_score)/((positive_score+negative_score)+0.000001)
print('polarity_score=', Polarity_Score)

#Subjectivity Score = (Positive Score + Negative Score)/ ((Total Words after cleaning) + 0.000001)
subjectiivity_score=(positive_score-negative_score)/((len(tokenize_text))+ 0.000001)
print('subjectivity_score',subjectiivity_score)

#Avg Sentence len
length=c.shape[0]
avg_length=[]
for i in range(0,length):
  avg_length.append(len(c['abc'].iloc[i]))
avg_senetence_length=sum(avg_length)/len(avg_length)
print('avg sentence length=', avg_senetence_length)

#complex
vowels=['a','e','i','o','u']
import re
count=0
complex_Word_Count=0
for i in tokenize_text:
  x=re.compile('[es|ed]$')
  if x.match(i.lower()):
   count+=0
  else:
    for j in i:
      if(j.lower() in vowels ):
        count+=1
  if(count>2):
   complex_Word_Count+=1
  count=0
#print('Complex Word Count = ',complex_Word_Count)

Percentage_of_Complex_words=complex_Word_Count/len(tokenize_text)
print('percentag of complex words= ',Percentage_of_Complex_words)

#Fog Index = 0.4 * (Average Sentence Length + Percentage of Complex words)
Fog_Index = 0.4 * (avg_senetence_length + Percentage_of_Complex_words)
print('fog index= ',Fog_Index )

#avg No of Word Per Sen
length=c.shape[0]
avg_length=[]
for i in range(0,length):
  a=[word.split( ) for word in c.iloc[i]]
  avg_length.append(len(a[0]))
  a=0
#avg
avg_no_of_words_per_sentence=sum(avg_length)/length
print("avg no of words per sentence= ",avg_no_of_words_per_sentence)

#COMPLEX COUNT
vowels=['a','e','i','o','u']
import re
count=0
complex_Word_Count=0
for i in tokenize_text:
  x=re.compile('[es|ed]$')
  if x.match(i.lower()):
   count+=0
  else:
    for j in i:
      if(j.lower() in vowels ):
        count+=1
  if(count>2):
   complex_Word_Count+=1
  count=0
print('complex words count=',  complex_Word_Count)


#Word Count
word_count=len(tokenize_text)
print('word count= ', word_count)


#Syllable Counts
vowels=['a','e','i','o','u']
import re
count=0
for i in tokenize_text:
  x=re.compile('[es|ed]$')
  if x.match(i.lower()):
   count+=0
  else:
    for j in i:
      if(j.lower() in vowels ):
        count+=1
syllable_count=count
print('syllable_per_word= ',syllable_count)


#Personal pronouns
pronouns=['i','we','my','ours','us' ]
import re
count=0
for i in tokenize_text:
  if i.lower() in pronouns:
   count+=1
personal_pronouns=count
print('personal pronouns= ',personal_pronouns )



#Avg Word Len
count=0
for i in tokenize_text:
  for j in i:
    count+=1
avg_word_length=count/len(tokenize_text)
print('avg word= ', avg_word_length)
# Out:
# postive score= 38
# negative score= 58
# polarity_score= -0.20833333116319447
# subjectivity_score -0.018501387586955235
# avg sentence length= 200.84848484848484
# percentag of complex words=  0.28122109158186864
# fog index=  80.45188237602669
# avg no of words per sentence=  31.636363636363637
# complex words count= 304
# word count=  1081
# syllable_per_word=  2114
# personal pronouns=  3
# avg word=  5.196114708603146

# %% [markdown]
# ---

# %%
data={'positive_score':positive_score,'negative_score':negative_score,'Polarity_Score':Polarity_Score,'subjectiivity_score':subjectiivity_score,'avg_senetence_length':avg_senetence_length,'Percentage_of_Complex_words':Percentage_of_Complex_words,'Fog_Index':Fog_Index,'avg_no_of_words_per_sentence':avg_no_of_words_per_sentence,'complex_Word_Count':complex_Word_Count,'word_count':word_count,'syllable_count':syllable_count,'personal_pronouns':personal_pronouns,'avg_word_length':avg_word_length}
output=pd.DataFrame()  #only once
output=output.append(data,ignore_index=True)
#output.columns=['positive_score','negative_score','Polarity_Score','subjectiivity_score','avg_senetence_length','Percentage_of_Complex_words','Fog_Index','avg_no_of_words_per_sentence','complex_Word_Count','word_count','syllable_count','personal_pronouns','avg_word_length']
output
